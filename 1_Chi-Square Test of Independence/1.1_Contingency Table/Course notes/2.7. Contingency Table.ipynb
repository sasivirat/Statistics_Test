# %%
import pandas as pd

# %%
df = pd.read_excel("2. Case 1 - Chi-square test of independence.xlsx")

# %%
df.head()
# Out:
#    Respondent        Uniqueness Purchase Likelihood
# 0           1  Extremely unique    Extremely likely
# 1           2  Extremely unique    Extremely likely
# 2           3  Extremely unique    Extremely likely
# 3           4  Extremely unique    Extremely likely
# 4           5  Extremely unique    Extremely likely

# %%
pd.crosstab(df["Uniqueness"],df["Purchase Likelihood"], margins=True, margins_name='Total')
# Out:
# Purchase Likelihood  Extremely likely  Not at all likely  Not so likely  \
# Uniqueness
# Extremely unique                   12                 10             10
# Not at all unique                   5                 11              5
# Not so unique                       7                  9             10
# Somewhat unique                    15                 16             15
# Very unique                        52                 30             30
# Total                              91                 76             70
#
# Purchase Likelihood  Somewhat likely  Very likely  Total
# Uniqueness
# Extremely unique                  13           25     70
# Not at all unique                  4            8     33
# Not so unique                      8           16     50
# Somewhat unique                   16           28     90
# Very unique                       64          104    280
# Total                            105          181    523

# %%
pd.crosstab(df["Uniqueness"],df["Purchase Likelihood"], margins=True, margins_name='Total',normalize=True).round(3)
# Out:
# Purchase Likelihood  Extremely likely  Not at all likely  Not so likely  \
# Uniqueness
# Extremely unique                0.023              0.019          0.019
# Not at all unique               0.010              0.021          0.010
# Not so unique                   0.013              0.017          0.019
# Somewhat unique                 0.029              0.031          0.029
# Very unique                     0.099              0.057          0.057
# Total                           0.174              0.145          0.134
#
# Purchase Likelihood  Somewhat likely  Very likely  Total
# Uniqueness
# Extremely unique               0.025        0.048  0.134
# Not at all unique              0.008        0.015  0.063
# Not so unique                  0.015        0.031  0.096
# Somewhat unique                0.031        0.054  0.172
# Very unique                    0.122        0.199  0.535
# Total                          0.201        0.346  1.000
